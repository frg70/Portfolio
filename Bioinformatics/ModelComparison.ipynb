# %% [markdown]
# # **Model creation and evaluation**

# %%
import pandas as pd
import seaborn as sns 
from sklearn.model_selection import train_test_split
import os

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
df = pd.read_csv(r'C:\Users\Fernando.DESKTOP-608G9HT\Documents\Cosas personales Fer\Job seeking\Portfolio\Bioinformatics\MKE_bioactivity_data_3class_pIC50_pubchem.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=2)

# %%
clf = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)

# %%
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:03<00:00, 11.18it/s]
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 42/42 [00:03<00:00, 13.41it/s]

# %%
predictions_train
# Out:
#                                             Adjusted R-Squared  \
# Model
# Lars                          75245187716760810073700171776.00
# SGDRegressor                                            628.20
# QuantileRegressor                                         1.02
# LassoLars                                                 1.02
# HistGradientBoostingRegressor                             1.02
# Lasso                                                     1.02
# LarsCV                                                    1.02
# LGBMRegressor                                             1.02
# DummyRegressor                                            1.02
# KNeighborsRegressor                                       1.02
# ElasticNetCV                                              1.01
# LassoLarsCV                                               1.01
# LassoCV                                                   1.01
# ElasticNet                                                1.01
# PassiveAggressiveRegressor                                1.01
# NuSVR                                                     1.01
# SVR                                                       1.01
# BaggingRegressor                                          1.00
# OrthogonalMatchingPursuitCV                               1.00
# RandomForestRegressor                                     1.00
# KernelRidge                                               1.00
# GammaRegressor                                            1.00
# TweedieRegressor                                          1.00
# PoissonRegressor                                          1.00
# RidgeCV                                                   1.00
# MLPRegressor                                              1.00
# HuberRegressor                                            1.00
# Ridge                                                     1.00
# AdaBoostRegressor                                         1.00
# XGBRegressor                                              1.00
# LinearSVR                                                 1.00
# GradientBoostingRegressor                                 1.00
# BayesianRidge                                             1.00
# OrthogonalMatchingPursuit                                 1.00
# DecisionTreeRegressor                                     1.00
# LinearRegression                                          1.00
# ExtraTreeRegressor                                        1.00
# TransformedTargetRegressor                                1.00
# GaussianProcessRegressor                                  1.00
# ExtraTreesRegressor                                       1.00
#
#                                                         R-Squared  \
# Model
# Lars                          -4670576294704652902080163348480.00
# SGDRegressor                                            -38930.37
# QuantileRegressor                                           -0.15
# LassoLars                                                    0.00
# HistGradientBoostingRegressor                                0.00
# Lasso                                                        0.00
# LarsCV                                                       0.00
# LGBMRegressor                                                0.00
# DummyRegressor                                               0.00
# KNeighborsRegressor                                          0.04
# ElasticNetCV                                                 0.12
# LassoLarsCV                                                  0.16
# LassoCV                                                      0.19
# ElasticNet                                                   0.30
# PassiveAggressiveRegressor                                   0.56
# NuSVR                                                        0.59
# SVR                                                          0.62
# BaggingRegressor                                             0.74
# OrthogonalMatchingPursuitCV                                  0.79
# RandomForestRegressor                                        0.87
# KernelRidge                                                  0.97
# GammaRegressor                                               0.98
# TweedieRegressor                                             0.99
# PoissonRegressor                                             0.99
# RidgeCV                                                      0.99
# MLPRegressor                                                 1.00
# HuberRegressor                                               1.00
# Ridge                                                        1.00
# AdaBoostRegressor                                            1.00
# XGBRegressor                                                 1.00
# LinearSVR                                                    1.00
# GradientBoostingRegressor                                    1.00
# BayesianRidge                                                1.00
# OrthogonalMatchingPursuit                                    1.00
# DecisionTreeRegressor                                        1.00
# LinearRegression                                             1.00
# ExtraTreeRegressor                                           1.00
# TransformedTargetRegressor                                   1.00
# GaussianProcessRegressor                                     1.00
# ExtraTreesRegressor                                          1.00
#
#                                              RMSE  Time Taken
# Model
# Lars                          1790616769092888.25        0.21
# SGDRegressor                               163.48        0.03
# QuantileRegressor                            0.89        0.09
# LassoLars                                    0.83        0.03
# HistGradientBoostingRegressor                0.83        0.14
# Lasso                                        0.83        0.03
# LarsCV                                       0.83        0.27
# LGBMRegressor                                0.83        0.14
# DummyRegressor                               0.83        0.02
# KNeighborsRegressor                          0.81        0.21
# ElasticNetCV                                 0.78        0.43
# LassoLarsCV                                  0.76        0.08
# LassoCV                                      0.74        0.20
# ElasticNet                                   0.69        0.03
# PassiveAggressiveRegressor                   0.55        0.04
# NuSVR                                        0.53        0.03
# SVR                                          0.51        0.02
# BaggingRegressor                             0.42        0.04
# OrthogonalMatchingPursuitCV                  0.38        0.04
# RandomForestRegressor                        0.30        0.14
# KernelRidge                                  0.15        0.07
# GammaRegressor                               0.11        0.07
# TweedieRegressor                             0.10        0.13
# PoissonRegressor                             0.08        0.10
# RidgeCV                                      0.07        0.03
# MLPRegressor                                 0.02        0.14
# HuberRegressor                               0.01        0.15
# Ridge                                        0.01        0.03
# AdaBoostRegressor                            0.01        0.11
# XGBRegressor                                 0.00        0.12
# LinearSVR                                    0.00        0.03
# GradientBoostingRegressor                    0.00        0.08
# BayesianRidge                                0.00        0.05
# OrthogonalMatchingPursuit                    0.00        0.03
# DecisionTreeRegressor                        0.00        0.03
# LinearRegression                             0.00        0.03
# ExtraTreeRegressor                           0.00        0.02
# TransformedTargetRegressor                   0.00        0.03
# GaussianProcessRegressor                     0.00        0.07
# ExtraTreesRegressor                          0.00        0.11

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
